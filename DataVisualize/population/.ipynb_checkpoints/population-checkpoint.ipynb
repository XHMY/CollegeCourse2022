# %%
import pandas as pd
import numpy as np

# %%
from lets_plot import *
LetsPlot.setup_html(offline=True)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [21], in <cell line: 1>()
# ----> 1 from lets_plot import *
#       2 LetsPlot.setup_html(offline=True)
#
# File C:\ProgramData\Miniconda3\lib\site-packages\lets_plot\__init__.py:17, in <module>
#      15 from .plot import *
#      16 from .export import *
# ---> 17 from .frontend_context import *
#      18 from .settings_utils import *
#      19 from .bistro import *
#
# File C:\ProgramData\Miniconda3\lib\site-packages\lets_plot\frontend_context\__init__.py:6, in <module>
#       1 #
#       2 # Copyright (c) 2019. JetBrains s.r.o.
#       3 # Use of this source code is governed by the MIT license that can be found in the LICENSE file.
#       4 #
# ----> 6 from ._configuration import *
#       8 __all__ = _configuration.__all__
#
# ...

# %%
data = pd.read_csv("WPP2019_TotalPopulationBySex.csv")
data.head()
# Out:
#    LocID     Location  VarID Variant  Time  MidPeriod   PopMale  PopFemale  \
# 0      4  Afghanistan      2  Medium  1950     1950.5  4099.243   3652.874
# 1      4  Afghanistan      2  Medium  1951     1951.5  4134.756   3705.395
# 2      4  Afghanistan      2  Medium  1952     1952.5  4174.450   3761.546
# 3      4  Afghanistan      2  Medium  1953     1953.5  4218.336   3821.348
# 4      4  Afghanistan      2  Medium  1954     1954.5  4266.484   3884.832
#
#    PopTotal  PopDensity
# 0  7752.117      11.874
# 1  7840.151      12.009
# 2  7935.996      12.156
# 3  8039.684      12.315
# 4  8151.316      12.486

# %%
data = data[data["Variant"]=="Medium"]

# %%
data[(data["Time"]==2021) & (data["Location"]=="China")]
# Out:
#        LocID Location  VarID Variant  Time  MidPeriod     PopMale   PopFemale  \
# 47824    156    China      2  Medium  1950     1950.5  287739.865  266679.404
# 47825    156    China      2  Medium  1951     1951.5  295567.965  274341.143
# 47826    156    China      2  Medium  1952     1952.5  301939.824  280636.673
# 47827    156    China      2  Medium  1953     1953.5  307333.563  286032.319
# 47828    156    China      2  Medium  1954     1954.5  312143.382  290908.934
# ...      ...      ...    ...     ...   ...        ...         ...         ...
# 47970    156    China      2  Medium  2096     2096.5  556775.037  529896.299
# 47971    156    China      2  Medium  2097     2097.5  553796.475  527461.597
# 47972    156    China      2  Medium  2098     2098.5  550817.703  525037.152
# 47973    156    China      2  Medium  2099     2099.5  547828.515  522612.036
# 47974    156    China      2  Medium  2100     2100.5  544818.071  520175.386
#
#           PopTotal  PopDensity
# ...
